# %%
import cv2
import numpy as np
from tqdm import tqdm

from tennis_tracker.download_data.extract_keypoints import read_json_file

FILE_PATH = (
    "/Users/derek/Desktop/tennis_tracker/tennis_tracker/ball_tracking/labels.json"
)
FPS = 30
FRAME_WIDTH, FRAME_HEIGHT = 640, 480
COURT_HEIGHT = 799
COURT_WIDTH = 560
VIDEO_PATH = "/Users/derek/Desktop/tennis_tracker/tennis_tracker/download_data/dataset/Tiafoe Takes On Evans; Khachanov& Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU].webm"


def get_next_frame(data_entry: dict, court_image: np.array):
    """We want to get tracked points and draw them on the court image"""
    tracked_points = data_entry["ball_tracking_transformed_coords"]
    ball_tracking_boxes = data_entry["ball_tracking_boxes"]
    ball_tracking_boxes = [x.split(" ") for x in ball_tracking_boxes]
    ball_tracking_boxes = [[float(y) for y in x[1:]] for x in ball_tracking_boxes]
    original_image = cv2.imread(data_entry["actual_path"])
    original_image = cv2.resize(original_image, (640, 480))
    # for point, box in zip(tracked_points, ball_tracking_boxes):
    #     cv2.circle(court_image, [int(p) for p in point], 10, (0, 0, 255), -1)
    #     cv2.circle(original_image, [int(box[0] * 640), int(box[1] * 480)], 10, (0, 0, 255), -1)
    return original_image, tracked_points

def clean_ball_tracking_boxes(ball_tracking_boxes: list[list[float]]) -> list[list[float]]:
    return [[x[0] * 640, x[1] * 480] for x in ball_tracking_boxes]


data = read_json_file(FILE_PATH)

tiafoe_video_frames = []
keys = list(data.keys())
for key in keys:
    if "Tiafoe" in key:
        tiafoe_video_frames.append((key, int(key.split("/")[-1].split(".")[0])))

tiafoe_video_frames.sort(key=lambda x: x[1])
tiafoe_video_frames = [x[0] for x in tiafoe_video_frames]
video_capture = cv2.VideoCapture(VIDEO_PATH)
FPS = video_capture.get(cv2.CAP_PROP_FPS)


all_objects = []
for i in tqdm(range(len(tiafoe_video_frames[:3000]))):
    court_image = cv2.imread(
        "/Users/derek/Desktop/tennis_tracker/tennis_tracker/player_location/padded_court.jpg"
    )
    ball_tracking_boxes = data[tiafoe_video_frames[i]]["ball_tracking_boxes"]
    ball_tracking_boxes = clean_ball_tracking_boxes(ball_tracking_boxes)
# Out:
# [('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/126.png', 126), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/127.png', 127), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/128.png', 128), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/129.png', 129), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/130.png', 130), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/131.png', 131), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/132.png', 132), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/133.png', 133), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/134.png', 134), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/135.png', 135), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/136.png', 136), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/137.png', 137), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/138.png', 138), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/139.png', 139), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/140.png', 140), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/141.png', 141), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/142.png', 142), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/143.png', 143), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/144.png', 144), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/145.png', 145), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe Takes On Evans; Khachanov & Mannarino Also In Action ｜ Almaty 2024 Highlights Day 4 [Q1iTjk444RU]/146.png', 146), ('/home/da2986/tennis_tracker/tennis_tracker/download_data/frames/Tiafoe ...
